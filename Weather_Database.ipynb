# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 746

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    city_url = url +"&q=" + city.replace(" ","+")
    print(f"Processing {i} = {city}")
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weatherdescription = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Weather": city_weatherdescription})
    except:
        print("Error: Process skipped")
        pass
        
        
# Print the end of the logging.
print("-----------------------------")     
print("Ending Data Retrieval     ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing 0 = amahai
# Processing 1 = rikitea
# Processing 2 = leningradskiy
# Processing 3 = ushuaia
# Processing 4 = cidreira
# Processing 5 = busselton
# Processing 6 = weligama
# Processing 7 = ondjiva
# Processing 8 = butaritari
# Processing 9 = ailigandi
# Processing 10 = codrington
# Processing 11 = calabozo
# Processing 12 = kuusankoski
# Processing 13 = the valley
# Processing 14 = stoyba
# Error: Process skipped
# Processing 15 = isangel
# Processing 16 = punta arenas
# Processing 17 = bredasdorp
# Processing 18 = saleaula
# Error: Process skipped
# Processing 19 = abha
# Processing 20 = brainerd
# Processing 21 = belushya guba
# Error: Process skipped
# Processing 22 = albany
# Processing 23 = dikson
# Processing 24 = atuona
# Processing 25 = vaini
# Processing 26 = avarua
# Processing 27 = atar
# Processing 28 = tuktoyaktuk
# Processing 29 = provideniya
# Processing 30 = pevek
# Processing 31 = fortuna
# Processing 32 = varadia
# Processing 33 = gasa
# Processing 34 = lorengau
# Processing 35 = willowmore
# Processing 36 = kedrovyy
# Processing 37 = qaanaaq
# Processing 38 = thinadhoo
# Processing 39 = saldanha
# Processing 40 = lithakia
# Processing 41 = wonthaggi
# Processing 42 = puerto ayora
# Processing 43 = mataura
# Processing 44 = new norfolk
# Processing 45 = almaznyy
# Processing 46 = walvis bay
# Processing 47 = jamalpur
# Processing 48 = daxian
# Error: Process skipped
# Processing 49 = iqaluit
# Processing 50 = makakilo city
# Processing 51 = berlevag
# Processing 52 = broome
# Processing 53 = cape town
# Processing 54 = belmonte
# Processing 55 = cayenne
# Processing 56 = omboue
# Processing 57 = nizhneyansk
# Error: Process skipped
# Processing 58 = waren
# Processing 59 = diego de almagro
# Processing 60 = jamestown
# Processing 61 = attawapiskat
# Error: Process skipped
# Processing 62 = wulanhaote
# Error: Process skipped
# Processing 63 = slave lake
# Processing 64 = kodiak
# Processing 65 = orlik
# Processing 66 = tual
# Processing 67 = saint george
# Processing 68 = maralal
# Processing 69 = serenje
# Processing 70 = shahr-e babak
# Processing 71 = port elizabeth
# Processing 72 = aswan
# Processing 73 = kruisfontein
# Processing 74 = westport
# Processing 75 = sao filipe
# Processing 76 = tabiauea
# Error: Process skipped
# Processing 77 = danjiangkou
# Processing 78 = pundaguitan
# Processing 79 = saskylakh
# Processing 80 = kapaa
# Processing 81 = sataua
# Error: Process skipped
# Processing 82 = nisia floresta
# Processing 83 = ahuimanu
# Processing 84 = mahebourg
# Processing 85 = ilulissat
# Processing 86 = hermanus
# Processing 87 = utiroa
# Error: Process skipped
# Processing 88 = harper
# Processing 89 = bargal
# Error: Process skipped
# Processing 90 = pisco
# Processing 91 = lavrentiya
# Processing 92 = mandalgovi
# Processing 93 = saint-philippe
# Processing 94 = longyearbyen
# Processing 95 = severo-kurilsk
# Processing 96 = nicoya
# Processing 97 = madison
# Processing 98 = taolanaro
# Error: Process skipped
# Processing 99 = tiksi
# Processing 100 = khatanga
# Processing 101 = toliary
# Error: Process skipped
# Processing 102 = christchurch
# Processing 103 = ocampo
# Processing 104 = turbat
# Processing 105 = mys shmidta
# Error: Process skipped
# Processing 106 = tuatapere
# Processing 107 = goderich
# Processing 108 = mitu
# Processing 109 = gardan diwal
# Error: Process skipped
# Processing 110 = yulara
# Processing 111 = cabo san lucas
# Processing 112 = kibala
# Processing 113 = ribeira grande
# Processing 114 = illoqqortoormiut
# Error: Process skipped
# Processing 115 = saint anthony
# Processing 116 = cherskiy
# Processing 117 = antalaha
# Processing 118 = valdivia
# Processing 119 = yellowknife
# Processing 120 = hasaki
# Processing 121 = sinnamary
# Processing 122 = bohdan
# Processing 123 = ascope
# Processing 124 = thaton
# Processing 125 = saint-augustin
# Processing 126 = viedma
# Processing 127 = waddan
# Processing 128 = thompson
# Processing 129 = leon valley
# Processing 130 = flin flon
# Processing 131 = pasaje
# Processing 132 = port alfred
# Processing 133 = mount darwin
# Processing 134 = hilo
# Processing 135 = bluff
# Processing 136 = cabedelo
# Processing 137 = chokurdakh
# Processing 138 = luderitz
# Processing 139 = sao gabriel da cachoeira
# Processing 140 = barrow
# Processing 141 = srednekolymsk
# Processing 142 = bambous virieux
# Processing 143 = torbay
# Processing 144 = parlier
# Processing 145 = grand river south east
# Error: Process skipped
# Processing 146 = seymchan
# Processing 147 = georgetown
# Processing 148 = ponta do sol
# Processing 149 = arraial do cabo
# Processing 150 = kindu
# Processing 151 = asau
# Processing 152 = amderma
# Error: Process skipped
# Processing 153 = port moresby
# Processing 154 = coruripe
# Processing 155 = vanimo
# Processing 156 = aybak
# Error: Process skipped
# Processing 157 = mar del plata
# Processing 158 = huescar
# Processing 159 = vaitupu
# Error: Process skipped
# Processing 160 = carnarvon
# Processing 161 = sitka
# Processing 162 = port arthur
# Processing 163 = bilma
# Processing 164 = pacific grove
# Processing 165 = carbonia
# Processing 166 = bud
# Processing 167 = martapura
# Processing 168 = alta floresta
# Processing 169 = rabinal
# Processing 170 = razole
# Processing 171 = shu
# Processing 172 = jurm
# Processing 173 = nuuk
# Processing 174 = inhambane
# Processing 175 = sao joao da barra
# Processing 176 = dunedin
# Processing 177 = yar-sale
# Processing 178 = diffa
# Processing 179 = clyde river
# Processing 180 = esperance
# Processing 181 = catuday
# Processing 182 = san patricio
# Processing 183 = te anau
# Processing 184 = poltavka
# Processing 185 = yuncheng
# Processing 186 = ustrzyki dolne
# Processing 187 = canora
# Processing 188 = daru
# Processing 189 = samalaeulu
# Error: Process skipped
# Processing 190 = fort morgan
# Processing 191 = creel
# Processing 192 = deputatskiy
# Processing 193 = salalah
# Processing 194 = alvdal
# Processing 195 = nanortalik
# Processing 196 = constantine
# Processing 197 = yilan
# Processing 198 = wajir
# Processing 199 = lebu
# Processing 200 = la paz
# Processing 201 = vardo
# Processing 202 = west bay
# Processing 203 = kralendijk
# Processing 204 = formoso do araguaia
# Error: Process skipped
# Processing 205 = upernavik
# Processing 206 = kahramanmaras
# Processing 207 = denpasar
# Processing 208 = ancud
# Processing 209 = lompoc
# Processing 210 = lanzhou
# Processing 211 = kalach-na-donu
# Processing 212 = tilichiki
# Processing 213 = victoria
# Processing 214 = turtkul
# Error: Process skipped
# Processing 215 = college
# Processing 216 = cagayan de tawi-tawi
# Error: Process skipped
# Processing 217 = kirakira
# Processing 218 = bengkulu
# Processing 219 = liuzhou
# Processing 220 = san jeronimo
# Processing 221 = lianzhou
# Processing 222 = ushtobe
# Processing 223 = geresk
# Error: Process skipped
# Processing 224 = roman
# Processing 225 = tieli
# Processing 226 = mamontovo
# Processing 227 = samusu
# Error: Process skipped
# Processing 228 = east london
# Processing 229 = kodinsk
# Processing 230 = tsihombe
# Error: Process skipped
# Processing 231 = vilhena
# Processing 232 = cascais
# Processing 233 = balikpapan
# Processing 234 = sarkand
# Processing 235 = quartucciu
# Processing 236 = kaitangata
# Processing 237 = faanui
# Processing 238 = abu dhabi
# Processing 239 = bethel
# Processing 240 = hobart
# Processing 241 = cap malheureux
# Processing 242 = bilibino
# Processing 243 = baykit
# Processing 244 = harnosand
# Processing 245 = port lincoln
# Processing 246 = zyryanka
# Processing 247 = la union
# Processing 248 = la rioja
# Processing 249 = saint-paul
# Processing 250 = bundaberg
# Processing 251 = san policarpo
# Processing 252 = barentsburg
# Error: Process skipped
# Processing 253 = pekan
# Processing 254 = mentok
# Error: Process skipped
# Processing 255 = katha
# Error: Process skipped
# Processing 256 = amasya
# Processing 257 = batagay-alyta
# Processing 258 = san cristobal
# Processing 259 = lagoa
# Processing 260 = honningsvag
# Processing 261 = koumac
# Processing 262 = vostok
# Processing 263 = maltahohe
# Processing 264 = hithadhoo
# Processing 265 = cabra
# Processing 266 = bonthe
# Processing 267 = bolungarvik
# Error: Process skipped
# Processing 268 = aklavik
# Processing 269 = norman wells
# Processing 270 = hoshiarpur
# Processing 271 = megion
# Processing 272 = harrison
# Processing 273 = karratha
# Processing 274 = effingham
# Processing 275 = les cayes
# Processing 276 = vitry-le-francois
# Processing 277 = najran
# Processing 278 = mitchell
# Processing 279 = dinajpur
# Processing 280 = shawnee
# Processing 281 = seversk
# Processing 282 = newport
# Processing 283 = saint-francois
# Processing 284 = chagda
# Error: Process skipped
# Processing 285 = tasiilaq
# Processing 286 = necochea
# Processing 287 = isla vista
# Processing 288 = loa janan
# Processing 289 = bathsheba
# Processing 290 = klaksvik
# Processing 291 = chapais
# Processing 292 = vestmanna
# Processing 293 = mbanza-ngungu
# Processing 294 = leua
# Processing 295 = ozernovskiy
# Processing 296 = conde
# Processing 297 = dingle
# Processing 298 = avera
# Processing 299 = padang
# Processing 300 = nikolskoye
# Processing 301 = rawson
# Processing 302 = trairi
# Processing 303 = iquique
# Processing 304 = zhigansk
# Processing 305 = ranfurly
# Processing 306 = darasun
# Processing 307 = zaraza
# Processing 308 = tapaua
# Error: Process skipped
# Processing 309 = hobyo
# Processing 310 = dakar
# Processing 311 = waipawa
# Processing 312 = sentyabrskiy
# Error: Process skipped
# Processing 313 = port blair
# Processing 314 = talcahuano
# Processing 315 = mwinilunga
# Processing 316 = saiha
# Processing 317 = canaries
# Processing 318 = langsa
# Processing 319 = beringovskiy
# Processing 320 = caldwell
# Processing 321 = sumkino
# Processing 322 = santa cruz cabralia
# Processing 323 = zerbst
# Processing 324 = flinders
# Processing 325 = kudus
# Processing 326 = myitkyina
# Processing 327 = natal
# Processing 328 = moron
# Processing 329 = san rafael
# Processing 330 = grand-lahou
# Processing 331 = esso
# Processing 332 = talnakh
# Processing 333 = bardstown
# Processing 334 = campos
# Processing 335 = sechura
# Processing 336 = beyneu
# Processing 337 = mecca
# Processing 338 = carutapera
# Processing 339 = san vicente
# Processing 340 = huai thalaeng
# Processing 341 = vila
# Processing 342 = nortelandia
# Processing 343 = jequie
# Processing 344 = mehamn
# Processing 345 = broken hill
# Processing 346 = vigrestad
# Processing 347 = manokwari
# Processing 348 = kytlym
# Error: Process skipped
# Processing 349 = komsomolskiy
# Processing 350 = pingliang
# Processing 351 = redlands
# Processing 352 = la ronge
# Processing 353 = okulovka
# Processing 354 = hirara
# Processing 355 = ngukurr
# Error: Process skipped
# Processing 356 = chuy
# Processing 357 = oneonta
# Processing 358 = matara
# Processing 359 = coquimbo
# Processing 360 = shimoda
# Processing 361 = bandarbeyla
# Processing 362 = nome
# Processing 363 = hofn
# Processing 364 = bereda
# Processing 365 = puerto madryn
# Processing 366 = bridgetown
# Processing 367 = sangmelima
# Processing 368 = coihueco
# Processing 369 = ziro
# Processing 370 = port macquarie
# Processing 371 = ravar
# Processing 372 = imeni poliny osipenko
# Processing 373 = novopokrovka
# Processing 374 = nabire
# Processing 375 = sena madureira
# Processing 376 = yaan
# Processing 377 = rundu
# Processing 378 = dzilam gonzalez
# Processing 379 = labuan
# Processing 380 = kalmunai
# Processing 381 = jennings
# Processing 382 = bialogard
# Processing 383 = eureka
# Processing 384 = port shepstone
# Processing 385 = vao
# Processing 386 = urumqi
# Processing 387 = okhotsk
# Processing 388 = qasigiannguit
# Processing 389 = lakes entrance
# Processing 390 = ruatoria
# Error: Process skipped
# Processing 391 = coulommiers
# Processing 392 = boralday
# Processing 393 = semporna
# Processing 394 = manggar
# Processing 395 = romitan
# Processing 396 = petropavlovsk-kamchatskiy
# Processing 397 = ust-uda
# Processing 398 = narsaq
# Processing 399 = kazanlak
# Processing 400 = ipora
# Processing 401 = new albany
# Processing 402 = hokitika
# Processing 403 = tselinnoye
# Processing 404 = bubaque
# Processing 405 = souillac
# Processing 406 = krasnoselkup
# Processing 407 = wilmington
# Processing 408 = kiunga
# Processing 409 = kaoma
# Processing 410 = hualmay
# Processing 411 = pemangkat
# Processing 412 = villazon
# Processing 413 = ibanda
# Processing 414 = vila franca do campo
# Processing 415 = kuche
# Error: Process skipped
# Processing 416 = bokspits
# Error: Process skipped
# Processing 417 = san miguel
# Processing 418 = mutsamudu
# Error: Process skipped
# Processing 419 = warrensburg
# Processing 420 = partur
# Processing 421 = tazovskiy
# Processing 422 = geraldton
# Processing 423 = sondrio
# Processing 424 = hamilton
# Processing 425 = fairbanks
# Processing 426 = wattegama
# Processing 427 = bulnes
# Processing 428 = brae
# Processing 429 = san alberto
# Processing 430 = river falls
# Processing 431 = faya
# Processing 432 = castro
# Processing 433 = shipitsyno
# Processing 434 = cusuna
# Processing 435 = dakoro
# Processing 436 = oranjemund
# Processing 437 = kahului
# Processing 438 = vallenar
# Processing 439 = puerto triunfo
# Processing 440 = kerteh
# Error: Process skipped
# Processing 441 = farmington
# Processing 442 = odweyne
# Processing 443 = rafaela
# Processing 444 = constitucion
# Processing 445 = hong gai
# Processing 446 = nadym
# Processing 447 = sambava
# Processing 448 = yerbogachen
# Processing 449 = tumannyy
# Error: Process skipped
# Processing 450 = kattivakkam
# Processing 451 = lasa
# Processing 452 = awjilah
# Processing 453 = crestview
# Processing 454 = orthez
# Processing 455 = pangnirtung
# Processing 456 = virginia beach
# Processing 457 = betsiamites
# Processing 458 = chicama
# Processing 459 = muros
# Processing 460 = sandakan
# Processing 461 = hami
# Processing 462 = santa isabel do rio negro
# Processing 463 = trinidad
# Processing 464 = kaitong
# Processing 465 = san jose
# Processing 466 = balkanabat
# Processing 467 = nioro
# Processing 468 = maghama
# Error: Process skipped
# Processing 469 = douentza
# Processing 470 = illapel
# Processing 471 = monte alegre
# Processing 472 = yeniseysk
# Processing 473 = verkhnyaya inta
# Processing 474 = jumla
# Processing 475 = ahipara
# Processing 476 = touros
# Processing 477 = shenandoah
# Processing 478 = jurado
# Processing 479 = natitingou
# Processing 480 = antofagasta
# Processing 481 = baft
# Processing 482 = guarapari
# Processing 483 = conceicao do araguaia
# Processing 484 = havre-saint-pierre
# Processing 485 = jilib
# Processing 486 = usuki
# Processing 487 = roma
# Processing 488 = yeppoon
# Processing 489 = axim
# Processing 490 = sidney
# Processing 491 = teloloapan
# Processing 492 = guaratuba
# Processing 493 = ilhabela
# Processing 494 = airai
# Processing 495 = paita
# Processing 496 = umm lajj
# Processing 497 = naze
# Processing 498 = port hardy
# Processing 499 = palabuhanratu
# Error: Process skipped
# Processing 500 = camp verde
# Processing 501 = bogo
# Processing 502 = guanica
# Processing 503 = saryshagan
# Error: Process skipped
# Processing 504 = muleba
# Processing 505 = alice springs
# Processing 506 = tawkar
# Error: Process skipped
# Processing 507 = tiverton
# Processing 508 = doctor pedro p. pena
# Error: Process skipped
# Processing 509 = wanning
# Processing 510 = turukhansk
# Processing 511 = katsuura
# Processing 512 = hilton head island
# Processing 513 = dusti
# Processing 514 = cordoba
# Processing 515 = biatorbagy
# Processing 516 = fare
# Processing 517 = vasilyevskiy mokh
# Processing 518 = korla
# Processing 519 = abu zabad
# Processing 520 = gamba
# Processing 521 = pimentel
# Processing 522 = manicore
# Processing 523 = kavaratti
# Processing 524 = bireun
# Processing 525 = ostrovnoy
# Processing 526 = camacha
# Processing 527 = praia
# Processing 528 = muli
# Processing 529 = kedougou
# Processing 530 = vila velha
# Processing 531 = warrnambool
# Processing 532 = ilula
# Processing 533 = pijao
# Processing 534 = whitianga
# Processing 535 = belaya gora
# Processing 536 = makubetsu
# Processing 537 = ziway
# Processing 538 = panaba
# Processing 539 = dalvik
# Processing 540 = lewiston
# Processing 541 = san juan
# Processing 542 = tura
# Processing 543 = burgeo
# Processing 544 = verbilki
# Processing 545 = zhanatas
# Error: Process skipped
# Processing 546 = novo oriente
# Processing 547 = zharkent
# Processing 548 = tweed
# Processing 549 = agadez
# Processing 550 = douglas
# Processing 551 = barroualie
# Error: Process skipped
# Processing 552 = cardston
# Processing 553 = payakumbuh
# Processing 554 = kirovskaya
# Processing 555 = beaufort
# Processing 556 = acari
# Processing 557 = huaiyin
# Processing 558 = marcona
# Error: Process skipped
# Processing 559 = salina
# Processing 560 = sakakah
# Processing 561 = mergui
# Error: Process skipped
# Processing 562 = rodez
# Processing 563 = tautira
# Processing 564 = altagracia de orituco
# Processing 565 = seoul
# Processing 566 = tomatlan
# Processing 567 = geoagiu
# Processing 568 = velingara
# Processing 569 = foumban
# Processing 570 = sand
# Processing 571 = lata
# Processing 572 = marzuq
# Processing 573 = ossora
# Processing 574 = choa saidan shah
# Processing 575 = ixtapa
# Processing 576 = green valley
# Processing 577 = del rio
# Processing 578 = yekaterinovka
# Processing 579 = nhulunbuy
# Processing 580 = inirida
# Processing 581 = patratu
# Error: Process skipped
# Processing 582 = santa rosa
# Processing 583 = aketi
# Processing 584 = buraydah
# Processing 585 = alofi
# Processing 586 = spring hill
# Processing 587 = kavieng
# Processing 588 = jamshedpur
# Processing 589 = hambantota
# Processing 590 = kamaishi
# Processing 591 = yenagoa
# Processing 592 = muzhi
# Processing 593 = anapskaya
# Processing 594 = tandil
# Processing 595 = milkovo
# Processing 596 = korfovskiy
# Processing 597 = raudeberg
# Processing 598 = khani
# Processing 599 = umzimvubu
# Error: Process skipped
# Processing 600 = rio cuarto
# Processing 601 = colac
# Processing 602 = konokovo
# Processing 603 = eirunepe
# Processing 604 = katima mulilo
# Processing 605 = tenenkou
# Processing 606 = badarwas
# Processing 607 = shache
# Processing 608 = namibe
# Processing 609 = xuanhua
# Processing 610 = danielskuil
# Processing 611 = emilio carranza
# Processing 612 = ust-tsilma
# Processing 613 = cuamba
# Processing 614 = pacasmayo
# Processing 615 = big spring
# Processing 616 = merida
# Processing 617 = male
# Processing 618 = zhaotong
# Processing 619 = ca mau
# Processing 620 = grand gaube
# Processing 621 = lumphat
# Processing 622 = kjopsvik
# Processing 623 = thun
# Processing 624 = saumur
# Processing 625 = maragogi
# Processing 626 = kathu
# Processing 627 = beloha
# Processing 628 = predivinsk
# Processing 629 = guerrero negro
# Processing 630 = saryg-sep
# Processing 631 = viligili
# Error: Process skipped
# Processing 632 = nyimba
# Processing 633 = mamakan
# Processing 634 = bima
# Processing 635 = kunming
# Processing 636 = hanmer springs
# Processing 637 = port-gentil
# Processing 638 = san quintin
# Processing 639 = pocatello
# Processing 640 = bone
# Processing 641 = nazas
# Processing 642 = rio verde de mato grosso
# Processing 643 = puerto del rosario
# Processing 644 = bom jesus
# Processing 645 = labuhan
# Processing 646 = cimarron hills
# Processing 647 = victoria point
# Processing 648 = lensk
# Processing 649 = barawe
# Error: Process skipped
# Processing 650 = kamwenge
# Processing 651 = zhangye
# Processing 652 = linxia
# Processing 653 = champerico
# Processing 654 = winslow
# Processing 655 = huancavelica
# Processing 656 = chimbote
# Processing 657 = lenger
# Processing 658 = el faiyum
# Error: Process skipped
# Processing 659 = kabansk
# Processing 660 = olafsvik
# Processing 661 = caravelas
# Processing 662 = havoysund
# Processing 663 = kaeo
# Processing 664 = vagur
# Processing 665 = phan thiet
# Processing 666 = shubarshi
# Processing 667 = goulburn
# Processing 668 = kachug
# Processing 669 = mayo
# Processing 670 = moose factory
# Processing 671 = el alto
# Processing 672 = preobrazheniye
# Processing 673 = smithers
# Processing 674 = byron bay
# Processing 675 = rankovce
# Processing 676 = brownwood
# Processing 677 = lusambo
# Processing 678 = itarema
# Processing 679 = akdepe
# Processing 680 = aleksandrov gay
# Processing 681 = calkini
# Processing 682 = qaqortoq
# Processing 683 = haines junction
# Processing 684 = portland
# Processing 685 = dolores
# Processing 686 = prince rupert
# Processing 687 = marathokambos
# Error: Process skipped
# Processing 688 = freeport
# Processing 689 = bukan
# Processing 690 = clarin
# Processing 691 = russell
# Processing 692 = ndele
# Processing 693 = tubmanburg
# Processing 694 = novocheremshansk
# Processing 695 = bosaso
# Processing 696 = ust-nera
# Processing 697 = edmond
# Processing 698 = homer
# Processing 699 = tipitapa
# Processing 700 = eldikan
# Error: Process skipped
# Processing 701 = paramonga
# Processing 702 = pokhara
# Processing 703 = carballo
# Processing 704 = ouahigouya
# Processing 705 = stokmarknes
# Processing 706 = dubbo
# Processing 707 = esterhazy
# Processing 708 = kasongo-lunda
# Processing 709 = ayia galini
# Processing 710 = roquetas de mar
# Processing 711 = logumkloster
# Processing 712 = derzhavinsk
# Processing 713 = kankan
# Processing 714 = pochutla
# Processing 715 = koster
# Processing 716 = batemans bay
# Processing 717 = ojinaga
# Processing 718 = tortoli
# Processing 719 = asfi
# Processing 720 = port augusta
# Processing 721 = ngorongoro
# Processing 722 = babanka
# Processing 723 = quesnel
# Processing 724 = alpena
# Processing 725 = rocha
# Processing 726 = hay river
# Processing 727 = jacareacanga
# Processing 728 = markova
# Processing 729 = cooma
# Processing 730 = bossier city
# Processing 731 = xinyu
# Processing 732 = jiexiu
# Processing 733 = marga
# Processing 734 = andenes
# Processing 735 = batagay
# Processing 736 = ambon
# Processing 737 = fiumicino
# Processing 738 = bloemhof
# Processing 739 = noyabrsk
# Processing 740 = pinar del rio
# Processing 741 = aykhal
# Processing 742 = sola
# Processing 743 = chimore
# Processing 744 = frolishchi
# Processing 745 = kot samaba
# -----------------------------
# Ending Data Retrieval

# %%
# Add the array of dictionaries to a new Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Amahai      ID  -3.3333  128.9167     81.63        74          62
# 1        Rikitea      PF -23.1203 -134.9692     74.52        77          43
# 2  Leningradskiy      RU  69.3833  178.4167     34.32        94          26
# 3        Ushuaia      AR -54.8000  -68.3000     29.86        93          75
# 4       Cidreira      BR -30.1811  -50.2056     65.35        89          51
# 5      Busselton      AU -33.6500  115.3333     56.08        81          98
# 6       Weligama      LK   5.9667   80.4167     78.46        88         100
# 7        Ondjiva      AO -17.0667   15.7333     49.82        30           0
# 8     Butaritari      KI   3.0707  172.7902     82.87        68         100
# 9      Ailigandi      PA   9.2333  -78.0167     80.73        88         100
#
#    Wind Speed   Current Weather
# 0        2.84     broken clouds
# 1       12.30        light rain
# 2        9.71  scattered clouds
# 3        5.75     broken clouds
# 4        9.51     broken clouds
# 5        2.51   overcast clouds
# 6       11.10   overcast clouds
# 7        8.61         clear sky
# 8        4.68   overcast clouds
# 9        6.69   overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
